# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests as rq
import json
import time
import random
import csv 
import pickle

# %%
with open("data.pkl",'rb') as handle:
     d2 = pickle.load(handle)

# %%
d2.keys()
# Out:
# dict_keys(['Full name', 'Gender', 'Position', 'Nation', 'Institute', 'Shanghai_ranking', 'Depratment', 'Disciplines', 'Publications', 'Citations', 'Recommendations', 'Top_cited_research', 'Interest_score', 'Reads', 'h_index', 'URL'])

# %%
df = pd.DataFrame.from_dict(d2, orient='index')
df = df.transpose()

# %%
df
# Out:
#                  Full name Gender  \
# 0      Vladimir Al. Osipov   male
# 1            Ronens Sosnik   male
# 2             Jacob. Gavan   male
# 3             Y. Berkovich   male
# 4        Boris D. Fainberg   male
# ...                    ...    ...
# 1981             Dan Galai   male
# 1982  Gabi Michael Sheffer   male
# 1983            Zvi Wiener   male
# 1984           Mark Pinsky   male
# 1985            Lilach Nir   male
#
#                                                Position  Nation  \
# 0                                                   PhD  Israel
# 1                                       Senior Lecturer  Israel
# 2                          Full Professor   Fellow IEEE  Israel
# 3                                                   Dr.  Israel
# 4                                  Professor of Physics  Israel
# ...                                                 ...     ...
# 1981                                          Professor  Israel
# 1982  Professor (Full) at Hebrew University of Jerus...  Israel
# 1983                                                PhD  Israel
# 1984                                                Nan  Israel
# 1985                         Ph.D., Associate Professor  Israel
#
#                            Institute Shanghai_ranking  \
# 0      Holon-Institute-of-Technology              801
# 1      Holon-Institute-of-Technology              801
# 2      Holon-Institute-of-Technology              801
# 3      Holon-Institute-of-Technology              801
# 4      Holon-Institute-of-Technology              801
# ...                              ...              ...
# 1981  Hebrew University of Jerusalem               77
# 1982  Hebrew University of Jerusalem               77
# 1983  Hebrew University of Jerusalem               77
# 1984  Hebrew University of Jerusalem               77
# 1985  Hebrew University of Jerusalem               77
#
#                                              Depratment  \
# 0                                 Department of physics
# 1                                Faculty of Engineering
# 2                             Digital Signal Processing
# 3                                Faculty of Engineering
# 4            Faculty of Sciences, Department of Physics
# ...                                                 ...
# 1981                                            Finance
# 1982                    Department of Political Science
# 1983                  School of Business Administration
# 1984  Fredy and Nadine Herrmann Institute of Earth S...
# 1985                    Department of Political Science
#
#                                             Disciplines Publications  \
# 0             Nonlinear Dynamics|Statistics|Probability         38.0
# 1     Brain Imaging|Cognitive Neuroscience|Neuroimaging         43.0
# 2                                                   Nan         85.0
# 3            Power Electronic Systems|Power Electronics         70.0
# 4        Nanoelectronics|Nanotechnology|Optoelectronics        130.0
# ...                                                 ...          ...
# 1981  Banking|Credit Risk Management|Financial Risk ...          106
# 1982  International Relations Theory|International P...           35
# 1983  Credit Risk Management|Financial Risk Manageme...           87
# 1984                                                Nan          144
# 1985  Governance|Political Participation|Public Opinion           40
#
#      Citations Recommendations  \
# 0        762.0            61.0
# 1       1327.0            11.0
# 2        351.0             0.0
# 3       3038.0            51.0
# 4        923.0            16.0
# ...        ...             ...
# 1981     5,609              18
# 1982       710               0
# 1983       972              31
# 1984     5,474              24
# 1985     2,107               4
#
#                                      Top_cited_research Interest_score  \
# 0     p-Adic Models of Ultrametric Diffusion Constra...         3887.0
# 1     Transformation from temporal to rate coding in...         6945.0
# 2     Effects of desensitization on mobile radio sys...          990.0
# 3     Switched-Capacitor/Switched-Inductor Structure...         1668.0
# 4     Light-induced current in molecular tunneling j...         2967.0
# ...                                                 ...            ...
# 1981           Information Effect on the Bid-Ask Spread          371.3
# 1982                  Diaspora Politics: At Home Abroad          533.5
# 1983                General Properties of Option Prices          2,250
# 1984  Continuous Symmetry Measures. 5. The Classical...          1,163
# 1985  Does Disagreement Contribute to More Deliberat...           None
#
#         Reads h_index   URL
# 0      3403.0    14.0     h
# 1      8872.0    15.0     t
# 2      2775.0    10.0     t
# 3     27529.0    21.0     p
# 4      4846.0    18.0     s
# ...       ...     ...   ...
# 1981    2,618      12  None
# 1982   12,316      13  None
# 1983   18,399      39  None
# 1984   12,166      20  None
# 1985     None    None  None
#
# [1986 rows x 16 columns]
