# %%
import pandas as pd
gdp_table = pd.read_csv("GDP.csv")

# %%
gdp_table
# Out:
#     Country Code                                            Ranking  \
# 0            USA                                                  1
# 1            CHN                                                  2
# 2            JPN                                                  3
# 3            DEU                                                  4
# 4            IND                                                  5
# ..           ...                                                ...
# 235          NaN  .. Not available.  \nNote: Table list 217 econ...
# 236          NaN                                                NaN
# 237          NaN                                                NaN
# 238          NaN  GDP data source: http://data.worldbank.org/dat...
# 239          NaN  GDP projections:  http://data.worldbank.org/da...
#
#      Unnamed: 2        Economy Millions USD Unnamed: 5
# 0           NaN  United States     23315081        NaN
# ...

# %%
gdp_dict = dict()
for index , row in gdp_table.iterrows():
      gdp_dict[row['Economy']] = row['Millions USD']
print(gdp_dict)
# Out:
# {'United States': '23315081', 'China': '17734063', 'Japan': '4940878', 'Germany': '4259935', 'India': '3176295', 'United Kingdom': '3131378', 'France': '2957880', 'Italy': '2107703', 'Canada': '1988336', 'Korea, Rep.': '1810956', 'Russian Federation': '1778783', 'Brazil': '1608981', 'Australia': '1552667', 'Spain': '1427381', 'Mexico': '1272839', 'Indonesia': '1186093', 'Netherlands': '1012847', 'Saudi Arabia': '833541', 'Türkiye': '819035', 'Switzerland': '800640', 'Poland': '679445', 'Sweden': '635664', 'Belgium': '594104', 'Thailand': '505947', 'Ireland': '504183', 'Israel': '488527', 'Argentina': '487227', 'Norway': '482175', 'Austria': '480368', 'Nigeria': '440834', 'South Africa': '419015', 'Bangladesh': '416265', 'United Arab Emirates': '415022', 'Egypt, Arab Rep.': '404143', 'Denmark': '398303', 'Singapore': '396987', 'Philippines': '394086', 'Malaysia': '372981', 'Hong Kong SAR, China': '369176', 'Vietnam': '366138', 'Iran, Islamic Rep.': '359713', 'Pakistan': '348263', 'Chi
# ...
